# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

# %% [markdown]
# Representacion discreta del intervalo temporal $[-\pi, \pi]$
#  ---------------

# %%
N = 2**10 + 1 # 1025
L = np.pi 
w0 = 2
t = np.linspace(-L, L, N)

w = np.copy(t) 
omega = np.copy(t) 

fig, ax = plt.subplots(1,1,figsize=(18,4))
o1 = ax.plot(t, t, 'b-',  label='$t$')
ax.legend()

# %% [markdown]
# 1. Usando la escritura de seno con expoenciales complejas, si $x(t) = 2*\sin(\omega_0t) =  \frac{e^{i\omega_0t}-e^{-i\omega_0t}}{i}$, entonces
#
# $$\hat x(\omega) = \frac{2 \pi}{i}  \left( \delta(\omega-\omega_0) - \delta(\omega+\omega_0)   \right)  $$
#
# y luego
#
# $$|\hat x(\omega)| = 2\pi \left( \delta(\omega-\omega_0) + \delta(\omega+\omega_0)  \right) $$

# %%
for w0 in [1, .1, .01]: #  valores a w0
    x = 2*np.sin(w0*t)
    n_w0 = int((L+w0) * N/(2*L))
    minus_n_w0 = int((L-w0) * N/(2*L))
    xhatmod = 2*np.pi*(signal.unit_impulse(N, n_w0) + 2*0.5*signal.unit_impulse(N, minus_n_w0))

    fig, ax = plt.subplots(1, 2,figsize=(18,4))
    o1 = ax[0].plot(t, x, 'b-',  label='$x$')
    o2 = ax[1].plot(w, xhatmod, 'r-', label='modulo de $\hat x$')
    ax[0].legend()
    ax[1].legend()
    ax[0].set_title(f'$w0 = {w0}$')
    ax[1].set_title(f'$w0 = {w0}$')

# %% [markdown]
# 2. Usando la escritura de seno con expoenciales complejas, si $x(t) = 2*\sin(2\omega_0t+ \frac{2}{3}) =  \dfrac{e^{2i\omega_0t+\frac{2i}{3}}-e^{-2i\omega_0t-\frac{2i}{3}}}{i}$, entonces
#
# $$\hat x(\omega) = \frac{2 \pi}{i}  \left( e^{\frac{-2i}{3}}\delta(\omega-2\omega_0) - e^{\frac{2i}{3}}\delta(\omega+2\omega_0)   \right)  $$
#
# y luego
#
# $$|\hat x(\omega)| = 2\pi \left( \delta(\omega-2\omega_0) + \delta(\omega+2\omega_0)  \right) $$

# %%
for w0 in [1, .1, .01]: #  valores a w0 #  valores a w0
    x = 2*np.sin(2*w0*t+ (3/2))
    n_w0 = int((L+2*w0) * N/(2*L))
    minus_n_w0 = int((L-2*w0) * N/(2*L))
    xhatmod = 2*np.pi*(signal.unit_impulse(N, n_w0) + 2*0.5*signal.unit_impulse(N, minus_n_w0))

    fig, ax = plt.subplots(1, 2,figsize=(18,4))
    o1 = ax[0].plot(t, x, 'b-',  label='$x$')
    o2 = ax[1].plot(w, xhatmod, 'r-', label='modulo de $\hat x$')
    ax[0].legend()
    ax[1].legend()
    ax[0].set_title(f'$w0 = {w0}$')
    ax[1].set_title(f'$w0 = {w0}$')

# %% [markdown]
# 3.Usando la escritura de seno y el coseno con exponenciales complejas,
# si
# $$x(t) = 2\cos(\omega_0t)+\sin(\omega_0t) = \left(1-\dfrac{i}{2}\right)e^{it\omega_0}+\left(1+\dfrac{i}{2}\right)e^{-it\omega_0}  $$,
# entonces
#
# $$\hat x(\omega) = 2 \pi\left((2 + i)  \delta(\omega - \omega_o) + (2 - i)  \delta(\omega_0 + \omega) \right) $$
#
# y luego
#
# $$|\hat x(\omega)| = 2 \pi\sqrt{5}\left(  \delta(\omega - \omega_o) +   \delta(\omega_0 + \omega) \right) $$

# %%
for w0 in [1, .1, .01]:
    x = 2*np.cos(w0*t)+ np.sin(w0*t)
    n_w0 = int((L+w0) * N/(2*L))
    minus_n_w0 = int((L-w0) * N/(2*L))
    xhatmod = 2*np.pi*(signal.unit_impulse(N, n_w0) + 2*0.5*signal.unit_impulse(N, minus_n_w0))

    fig, ax = plt.subplots(1, 2,figsize=(18,4))
    o1 = ax[0].plot(t, x, 'b-',  label='$x$')
    o2 = ax[1].plot(w, xhatmod, 'r-', label='modulo de $\hat x$')
    ax[0].legend()
    ax[1].legend()
    ax[0].set_title(f'$w0 = {w0}$')
    ax[1].set_title(f'$w0 = {w0}$')

# %% [markdown]
# 4.Usando la escritura de seno y el coseno con exponenciales complejas,si  $x(t)=1$
#
# entonces
#
# $$\hat x(\omega) = 2 \pi\delta(\omega) $$
#
# y luego
#
# $$|\hat x(\omega)| = 2 \pi\delta(\omega) $$

# %%
for w0 in [1, .1, .01]:
x = 1
xhatmod = 2*np.pi*(signal.unit_impulse(N, n_w0) 
                   
fig, ax = plt.subplots(1, 2,figsize=(18,4))
o1 = ax[0].plot(t, x, 'b-',  label='$x$')
o2 = ax[1].plot(w, xhatmod, 'r-', label='modulo de $\hat x$')
ax[0].legend()
ax[1].legend()
# Out:
#   File "<ipython-input-63-237ae91d389e>", line 2
#     x = 1
#     ^
# IndentationError: expected an indented block

# %% [markdown]
#  Ejercicio 2 - Transformada de Fourier y Representacion Frecuencial
#  ---------------

# %% [markdown]
# 1.  Si $x(t) = e^{-at}\gamma(t)$, entonces
#
#
#
# \begin{eqnarray}
#   \hat x(\omega) &=& \int_0^\infty e^{-at} e^{-i \omega t} dt  \\
#                  &=& \int_0^\infty e^{-(a +i \omega) t} dt \\
#                  &=& \left[ \frac{e^{-(a +i \omega) t}}{-(a +i \omega)} \right]_0^\infty \\
#                  &=&  \frac{1}{(a +i \omega)}
# \end{eqnarray}

# %%
for a in [1, .1, .01]:
    
    x = np.exp(-a*t) 
    x[:int(N/2)-1] = 0
    xhat = 1/(a+1j*omega)

    fig, ax = plt.subplots(1,2,figsize=(18,4))
    o1 = ax[0].plot(t, x, 'b-', label='$x$')
    o2 = ax[1].plot(w, np.real(xhat), 'g-', label='parte real de $\hat x$')
    o2 = ax[1].plot(w, np.imag(xhat), 'm-', label='parte imaginaria de $\hat x$')
    o2 = ax[1].plot(w, np.abs(xhat), 'r-', label='modulo de $\hat x$')
    ax[0].legend()
    ax[1].legend()
    ax[0].set_title(f'$a = {a}$')
    ax[1].set_title(f'$a = {a}$')

# %% [markdown]
# 2. Si $x(t) = e^{-a|t|}$ con $a>0$ , entonces
#
#
# \begin{eqnarray}
#   \hat x(\omega) &=& \dfrac{2a}{a^2+\omega^2}.
# \end{eqnarray}

# %%
for a in [1, .1, .01]:
    
    x = np.exp(-a*np.abs(t))  
    xhat = 2*a/(np.power(a,2)+np.power(omega,2))
    
    fig, ax = plt.subplots(1,2,figsize=(18,4))
    o1 = ax[0].plot(t, x, 'b-', label='$x$')
    o2 = ax[1].plot(w, np.real(xhat), 'g-', label='parte real de $\hat{x}$')
    o2 = ax[1].plot(w, np.imag(xhat), 'm-', label='parte imaginaria de $\hat{x}$')
    o2 = ax[1].plot(w, np.abs(xhat), 'r-', label='modulo de $\hat{x}$')
    ax[0].legend()
    ax[1].legend()
    ax[0].set_title(f'$a = {a}$')
    ax[1].set_title(f'$a = {a}$')

# %% [markdown]
# 3. Si  $x(t) = \dfrac{1}{1+t^2}$ tomando $a=1$ y usando (2), entonces
#
#
# \begin{eqnarray}
#   \hat{x}(\omega)=\dfrac{e^{-|\omega|}}{2}
# \end{eqnarray}

# %%
x = 1/(1+np.power(t,2)) 
xhat = np.exp(-np.abs(omega))/2
fig, ax = plt.subplots(1,2,figsize=(18,4))
o1 = ax[0].plot(t, x, 'b-', label='$x$')
o2 = ax[1].plot(w, np.real(xhat), 'g-', label='parte real de $\hat{x}$')
o2 = ax[1].plot(w, np.imag(xhat), 'm-', label='parte imaginaria de $\hat{x}$')
o2 = ax[1].plot(w, np.abs(xhat), 'r-', label='modulo de $\hat{x}$')
ax[0].legend()
ax[1].legend()

# %% [markdown]
# 4. Si  $x(t) = \dfrac{1}{2-2t+t^2}$ usamos (3), entonces
#
#
# \begin{eqnarray}
#   \hat{x}(\omega)=)=e^{-i \omega} e^{-|\omega|}
# \end{eqnarray}

# %%
x = 1/(2-2*t+np.power(t,2)) 
xhat = np.exp(-1j*omega-np.abs(omega))/2

fig, ax = plt.subplots(1,2,figsize=(18,4))
o1 = ax[0].plot(t, x, 'b-', label='$x$')
o2 = ax[1].plot(w, np.real(xhat), 'g-', label='parte real de $\hat{x}$')
o2 = ax[1].plot(w, np.imag(xhat), 'm-', label='parte imaginaria de $\hat{x}$')
o2 = ax[1].plot(w, np.abs(xhat), 'r-', label='modulo de $\hat{x}$')
ax[0].legend()
ax[1].legend()

# %% [markdown]
# 5.  Si $x(t) = \dfrac{1}{(1+t^2)^2}$ , entonces

# %% [markdown]
# Ejercicio 3 - Filtro medio
# ---------------

# %% [markdown]
# Definimos la función rectangular por
#
# \begin{equation}
# \label{rect}
#     \Pi_T(t) =     \begin{cases}
#       \frac 1T & \text{si } |t| < \frac{T}{2}\\
#       \frac 1{2T} & \text{si } |t| = \frac{T}{2}  \\
#       0 & \text{si no}
#     \end{cases} \,.
# \end{equation}
#
# El filtro medio, parametrizado por $T>0$, calcula el promedio de la señal en una ventana deslizante de largo $T$.

# %% [markdown]
# 1. Su respuesta impulsional es la la función rectangular definida por:
#
# $$h(t) = \Pi_T(t - T/2)$$

# %%
N = 8*2**10 + 1 # 1025
L = 4*np.pi 

t = np.linspace(-L, L, N)
w = t

T = np.pi/2

h = np.zeros_like(t)

n_zero = int(N/2)-1
n_min = n_zero - int(T * N/(2*L))
n_max = n_zero + int(T * N/(2*L))
h[n_min:n_zero] = 1/T
h[n_zero] = 1/(2*T)
h[n_zero+1:n_max] = 1/T

# %% [markdown]
# 2. Para encontrar la respuesta impulsional, calculamos la transformada de Fourier de $h$:
#
# \begin{eqnarray}
#     \mathcal F (h)(\omega) &=& \frac 1T \int_{-T/2}^{T/2} e^{-i\omega t} dt \\
#     &=& \left[ - \frac{e^{-i\omega t}}{i\omega T} \right]_{-T/2}^{T/2} \\
#     &=& \frac{e^{i\omega T} - e^{-i\omega T}}{i\omega T}  \\
#     &=& \frac{\sin(\omega T)}{\omega T} \\
#     &=& \text{sinc}(\omega T)
# \end{eqnarray}

# %%
sc = np.zeros_like(w)
w_zero = int(N/2)
sc[w_zero] = 1
sc[:w_zero] = 1/T * np.sin(T*w)[:w_zero]/w[:w_zero]
sc[w_zero+1:] = 1/T * np.sin(T*w)[w_zero+1:]/w[w_zero+1:]

# %%
fig, ax = plt.subplots(1, 2,figsize=(18,4))
ax[0].plot(t, h, 'b-.',  label='$x$')
ax[0].legend()
ax[0].set_title('respuesta impusional filtro medio')

ax[1].plot(w, sc, 'r-.',  label='sinus cardinal')
ax[1].legend()
ax[1].set_title('respuesta impusional filtro medio')
# Out:
# Text(0.5, 1.0, 'respuesta impusional filtro medio')

# %% [markdown]
# 2.

# %% [markdown]
# A)$x(t)=1$
# \begin{eqnarray}
# L[1](t) &=& \int_{-\infty}^{+\infty} 1\cdot h(u)du\\
# &=& \int_0^{T} \frac{1}{T}du\\
# &=& 1
# \end{eqnarray}

# %% [markdown]
# B)$x(t)=\gamma(t)$
# \begin{eqnarray}
# L[\gamma](t) &=& \int_{-\infty}^{+\infty} \gamma(t-u) h(u)du\\
# &=& 1
# \end{eqnarray}

# %% [markdown]
# C)$x(t)=\cos(\omega_0 t)$
# \begin{eqnarray}
# L[\cos(\omega_0 t)](t)&=&\int_{-\infty}^{+\infty} \cos(\omega_0(t-u))h(u)du,\\
# &=& \frac{1}{T} \int_0^T \cos(\omega_0(t-u))du.\\
# &=&\frac{1}{\omega_0 T}\left(\sin(\omega_0t)-\sin(\omega_0(t-T)) \right).
# \end{eqnarray}

# %% [markdown]
# 3. Exprese la salida del sistema para $x(t) = \cos(\omega_0 t)$ de la forma
# $y(t) = A(\omega_0) cos(\omega_0 t + \phi(\omega_0))$.
#
# usandp c y propiedad de la resta de senos de distintos angulos, nos queda
# \begin{eqnarray}
# \frac{1}{\omega_0 T}\left(\sin(\omega_0t)-\sin(\omega_0(t-T)) \right)&=&\frac{2}{\omega_0 T}  \cos\left( \frac{\omega_0t+\omega_0(t-T)}{2} \right)\sin\left(\frac{\omega_0t-\omega_0(t-T)}{2} \right), \\
# &=&\frac{2}{\omega_0 T} \sin\left( \dfrac{\omega_o T}{2} \right)\cos\left(\omega_0t+ \frac{\omega_0(t-T)}{2} \right), \\
# &=& A(\omega_0)\cos(\omega_0 t + \phi(\omega_0)).
# \end{eqnarray}
#
#
# De donde $A(\omega_0)=\frac{2}{\omega_0 T} \sin\left( \dfrac{\omega_o T}{2} \right)$ y $\phi(\omega_0)=\dfrac{\omega_0(t-T)}{2}$.

# %% [markdown]
# 4.- Grafique $|A(\omega_0)|$ en función de $\omega_0$ para $T = 1$. Grafique también $\phi(\omega_0)$.

# %%
T=1
w0=np.copy(t)
A=np.sin(w0*T/2)/(w0*T/2)
phi =w0*t/2 -w0*T/2

fig, ax = plt.subplots(1,2,figsize=(18,4))
o1 = ax[0].plot(w0,np.abs(A),'b-',label = '$A(\omega_0)$')
o2 = ax[1].plot(w0, phi, 'g-', label='$ \phi(\omega_0) $')
ax[0].legend()
ax[1].legend();
# Out:
# <ipython-input-88-af6d2e7edcf9>:3: RuntimeWarning: invalid value encountered in true_divide
#   A=np.sin(w0*T/2)/(w0*T/2)

# %% [markdown]
# Ejercicio 4 - Diagrama de Bode
# ---------------

# %% [markdown]
# Un diagrama de Bode es una representación gráfica que sirve para caracterizar la función de transferencia $H$ de un sistema. Escribiendo la función de transferencia compleja como
#
# $$ H(w) = |H(w)|e^{i\arg(H(w))} $$
#
# el diagrama consta de dos gráficas separadas  de ordenadas en escala logarítmica de $w$ expresada en radianes por segundo (rad/s) y de ordenadas:
#
# * Magnitud (o ganancia) en decibeles (dB)
# $$G (w) = 20 \log_{10} (|H(w)|)$$
#
# * Fase en grados
# $$\Phi(w) = \arg(H(w)) = \tan^{-1} \left( \frac{Im(H(w))}{Re(H(w))} \right)$$

# %% [markdown]
# ### Un ejemplo utilizando el método TransferFunction de scipy.signal
#
# Consideremos el operador lineal invariante en el tiempo dado por la funcion de transferencia
#
# $$ H(\omega) = \frac{P(\omega)}{Q(\omega)} = \frac{\omega^2 + 3\omega + 3}{\omega^2 + 2\omega + 1}.$$
#
# Usando las funciones *TransferFunction* y *bode* del modulo *signal* del paquete *scipy*, podemos representar el sistema.

# %%
sys = signal.TransferFunction([1, 3, 3], [1, 2, 1])
w, mag, phase = signal.bode(sys)

fig, ax = plt.subplots(2, 1,figsize=(8,6))
ax[0].semilogx(w, mag, 'm-.',  label='magnitude')
ax[1].semilogx(w, phase, 'g-.',  label='fase')
ax[0].set_title('Diagrama de Bode')
ax[0].legend()
ax[0].set_ylabel('Magnitude (dB)')
ax[1].legend()
ax[1].set_ylabel('Fase (deg)')
ax[1].set_xlabel('Frecuencia (rad/sec)')
# Out:
# Text(0.5, 0, 'Frecuencia (rad/sec)')

# %% [markdown]
# ### Sistema eléctrico de primer orden
#
# La salida del sistema en función de la entrada esta dada por la ecuación diferencial:
#
# $$x(t) = RCy'(t) + y(t)$$
#
# Usando las propriedades de la Transformada de Fourier, la respuesta frecuencial:
#
# $$H(\omega) = \frac{Y(\omega)}{X(\omega)} = \frac{1}{RC i \omega }$$
#
# que la rescribimos
#
# $$H(\omega) = \frac{1}{1+i\frac{\omega}{\omega_0}}$$
#
# donde $\omega_0 = 1 / RC$ es la llamada **frecuencia de corte**.

# %% [markdown]
# ### Modulo de la función de transferencia

# %% [markdown]
# De la expresion de $H(\omega)$ obtenmos que
#
#
# $$|H(\omega)| = \frac{1}{\sqrt{1+ \frac{\omega^2}{\omega_c^2}}}$$
#
# y luego
#
# $$G(\omega) =  20 \log_{10} (|H(w)|) = -10 \log_{10}\left( 1+\frac{\omega^2}{\omega_c^2} \right).$$
#
# Observamos que
#
# $$ \lim_{\omega \to 0} G(\omega) = 0$$
#
# y que
#
# $$ \lim_{\omega \to \infty} G(\omega) = -10 \log_{10} \left( \frac{\omega^2}{\omega_c^2} \right)  = -20 \log_{10} \left(\omega \right) + 20 \log_{10} \left(\omega_c \right)$$
#
#
# Ademas, cuando $\omega=\omega_0$, se tiene
#
# $$G(\omega) = -10 \log_{10} (2) = -3 \text{dB}$$
#
# lo que se interpreta que el filtro atenua el espectro de una señal de $-3 \text{dB}$ en la frecuancia de corte.

# %%
w0 = 10
fig, ax = plt.subplots(2, 1,figsize=(8,6))
G = np.copy(w)
G = -10 * np.log10(1+w**2/w0**2)
ax[0].semilogx(w, G, 'm-.',  label=f'magnitude para $\omega_c = {w0}$')
ax[0].set_title('Diagrama de Bode')
ax[0].legend()
ax[0].set_ylabel('Magnitude (dB)')
plt.text(.5, 1.25,'This text starts at point (2,4)')
# Out:
# Text(0.5, 1.25, 'This text starts at point (2,4)')
